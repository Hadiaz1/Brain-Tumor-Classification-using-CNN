# %% [markdown]
# <a href="https://colab.research.google.com/github/Hadiaz1/Brain-Tumor-Classification-using-CNN/blob/main/Data_Augmentation_BrainTumorDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About the data:
# The dataset contains 2 folders: yes and no which contains 253 Brain MRI Images. The folder yes contains 155 Brain MRI Images that are tumorous and the folder no contains 98 Brain MRI Images that are non-tumorous

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import cv2
import imutils
import matplotlib.pyplot as plt
from os import listdir
import time    
from google.colab import drive
drive.mount('/content/drive')
# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from zipfile import ZipFile

with ZipFile("/content/drive/MyDrive/brain_tumor_dataset.zip","r") as zip:
  zip.extractall()
  print("done extracting")
# Out:
# done extracting

# %%
def augment_data(file_dir, n_generated_samples, save_to_dir):
    """
    Arguments:
        file_dir: A string representing the directory where images that we want to augment are found.
        n_generated_samples: A string representing the number of generated samples using the given image.
        save_to_dir: A string representing the directory in which the generated images will be saved.
    """
    
    data_gen = ImageDataGenerator(rotation_range=10, 
                                  width_shift_range=0.1, 
                                  height_shift_range=0.1, 
                                  shear_range=0.1, 
                                  brightness_range=(0.3, 1.0),
                                  horizontal_flip=True, 
                                  vertical_flip=True, 
                                  fill_mode='nearest'
                                 )

    
    for filename in listdir(file_dir):
        # load the image
        image = cv2.imread(file_dir + '/' + filename)
        # reshape the image
        image = image.reshape((1,)+image.shape)
        # prefix of the names for the generated sampels.
        save_prefix = 'aug_' + filename[:-4]
        # generate 'n_generated_samples' sample images
        i=0
        for batch in data_gen.flow(x=image, batch_size=1, save_to_dir=save_to_dir, 
                                           save_prefix=save_prefix, save_format='jpg'):
            i += 1
            if i > n_generated_samples:
                break

# %% [markdown]
# Remember that 61% of the data (155 images) are tumorous. And, 39% of the data (98 images) are non-tumorous.
# So, in order to balance the data we can generate 9 new images for every image that belongs to 'no' class and 6 images for every image that belongs the 'yes' class.

# %%
augmented_data_path = r"/content/archive/brain_tumor_dataset/augmented_data/"

# augment data for the examples with label equal to 'yes' representing tumurous examples
augment_data(file_dir=r"/content/archive/brain_tumor_dataset/yes", n_generated_samples=6, save_to_dir=augmented_data_path+'yes')
# augment data for the examples with label equal to 'no' representing non-tumurous examples
augment_data(file_dir=r"/content/archive/brain_tumor_dataset/no", n_generated_samples=9, save_to_dir=augmented_data_path+'no')

# %%
def data_summary(main_path):
    
    yes_path = main_path+'yes'
    no_path = main_path+'no'
        
    # number of files (images) that are in the the folder named 'yes' that represent tumorous (positive) examples
    m_pos = len(listdir(yes_path))
    # number of files (images) that are in the the folder named 'no' that represent non-tumorous (negative) examples
    m_neg = len(listdir(no_path))
    # number of all examples
    m = (m_pos+m_neg)
    
    pos_prec = (m_pos* 100.0)/ m
    neg_prec = (m_neg* 100.0)/ m
    
    print(f"Number of examples: {m}")
    print(f"Percentage of positive examples: {pos_prec}%, number of pos examples: {m_pos}") 
    print(f"Percentage of negative examples: {neg_prec}%, number of neg examples: {m_neg}")

# %%
data_summary(augmented_data_path)
# Out:
# Number of examples: 2063
# Percentage of positive examples: 52.49636451769268%, number of pos examples: 1083
# Percentage of negative examples: 47.50363548230732%, number of neg examples: 980

# %%
# !zip -r /content/archive.zip /content/archive/
# Out:
#   adding: content/archive/ (stored 0%)
#   adding: content/archive/brain_tumor_dataset/ (stored 0%)
#   adding: content/archive/brain_tumor_dataset/yes/ (stored 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y254.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y90.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y255.JPG (deflated 36%)
#   adding: content/archive/brain_tumor_dataset/yes/Y147.JPG (deflated 24%)
#   adding: content/archive/brain_tumor_dataset/yes/Y91.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/yes/Y18.JPG (deflated 36%)
#   adding: content/archive/brain_tumor_dataset/yes/Y60.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y247.JPG (deflated 32%)
#   adding: content/archive/brain_tumor_dataset/yes/Y251.JPG (deflated 29%)
#   adding: content/archive/brain_tumor_dataset/yes/Y76.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/yes/Y248.JPG (deflated 26%)
#   adding: content/archive/brain_tumor_dataset/yes/Y62.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y113.JPG (deflated 34%)
#   adding: content/archive/brain_tumor_dataset/yes/Y164.JPG (deflated 38%)
#   adding: content/archive/brain_tumor_dataset/yes/Y46.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y39.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/yes/Y19.JPG (deflated 34%)
#   adding: content/archive/brain_tumor_dataset/yes/Y188.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/yes/Y243.JPG (deflated 35%)
#   adding: content/archive/brain_tumor_dataset/yes/Y186.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/yes/Y30.jpg (stored 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y41.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/yes/Y155.JPG (deflated 27%)
#   adding: content/archive/brain_tumor_dataset/yes/Y29.jpg (deflated 15%)
#   adding: content/archive/brain_tumor_dataset/yes/Y20.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/yes/Y77.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/yes/Y53.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/yes/Y37.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/yes/Y250.jpg (stored 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y259.JPG (deflated 38%)
#   adding: content/archive/brain_tumor_dataset/yes/Y25.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/yes/Y187.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y245.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/yes/Y167.JPG (deflated 25%)
#   adding: content/archive/brain_tumor_dataset/yes/Y101.jpg (deflated 27%)
#   adding: content/archive/brain_tumor_dataset/yes/Y6.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/yes/Y170.JPG (deflated 27%)
#   adding: content/archive/brain_tumor_dataset/yes/Y28.jpg (deflated 14%)
#   adding: content/archive/brain_tumor_dataset/yes/Y97.JPG (deflated 33%)
#   adding: content/archive/brain_tumor_dataset/yes/Y32.jpg (deflated 10%)
#   adding: content/archive/brain_tumor_dataset/yes/Y51.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y23.JPG (deflated 37%)
#   adding: content/archive/brain_tumor_dataset/yes/Y14.jpg (deflated 36%)
#   adding: content/archive/brain_tumor_dataset/yes/Y7.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/yes/Y159.JPG (deflated 30%)
#   adding: content/archive/brain_tumor_dataset/yes/Y34.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y35.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/yes/Y67.JPG (deflated 35%)
#   adding: content/archive/brain_tumor_dataset/yes/Y71.JPG (deflated 28%)
#   adding: content/archive/brain_tumor_dataset/yes/Y52.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/yes/Y154.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/yes/Y183.jpg (deflated 6%)
#   adding: content/archive/brain_tumor_dataset/yes/Y50.JPG (deflated 31%)
#   adding: content/archive/brain_tumor_dataset/yes/Y169.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y12.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y193.JPG (deflated 31%)
#   adding: content/archive/brain_tumor_dataset/yes/Y31.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y109.JPG (deflated 30%)
#   adding: content/archive/brain_tumor_dataset/yes/Y11.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/yes/Y59.JPG (deflated 38%)
#   adding: content/archive/brain_tumor_dataset/yes/Y148.JPG (deflated 28%)
#   adding: content/archive/brain_tumor_dataset/yes/Y89.JPG (deflated 39%)
#   adding: content/archive/brain_tumor_dataset/yes/Y75.JPG (deflated 29%)
#   adding: content/archive/brain_tumor_dataset/yes/Y4.jpg (deflated 7%)
#   adding: content/archive/brain_tumor_dataset/yes/Y112.JPG (deflated 27%)
#   adding: content/archive/brain_tumor_dataset/yes/Y194.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y56.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y106.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y13.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y181.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y192.JPG (deflated 26%)
#   adding: content/archive/brain_tumor_dataset/yes/Y98.JPG (deflated 38%)
#   adding: content/archive/brain_tumor_dataset/yes/Y195.JPG (deflated 31%)
#   adding: content/archive/brain_tumor_dataset/yes/Y153.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/yes/Y22.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y253.JPG (deflated 35%)
#   adding: content/archive/brain_tumor_dataset/yes/Y103.jpg (deflated 6%)
#   adding: content/archive/brain_tumor_dataset/yes/Y161.JPG (deflated 28%)
#   adding: content/archive/brain_tumor_dataset/yes/Y45.JPG (deflated 31%)
#   adding: content/archive/brain_tumor_dataset/yes/Y47.JPG (deflated 25%)
#   adding: content/archive/brain_tumor_dataset/yes/Y10.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/yes/Y249.JPG (deflated 24%)
#   adding: content/archive/brain_tumor_dataset/yes/Y99.JPG (deflated 28%)
#   adding: content/archive/brain_tumor_dataset/yes/Y100.JPG (deflated 33%)
#   adding: content/archive/brain_tumor_dataset/yes/Y256.JPG (deflated 33%)
#   adding: content/archive/brain_tumor_dataset/yes/Y184.JPG (deflated 49%)
#   adding: content/archive/brain_tumor_dataset/yes/Y111.JPG (deflated 28%)
#   adding: content/archive/brain_tumor_dataset/yes/Y104.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y115.JPG (deflated 31%)
#   adding: content/archive/brain_tumor_dataset/yes/Y73.jpg (deflated 30%)
#   adding: content/archive/brain_tumor_dataset/yes/Y38.jpg (stored 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y9.jpg (deflated 10%)
#   adding: content/archive/brain_tumor_dataset/yes/Y1.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/yes/Y54.jpg (stored 0%)
#   adding: content/archive/brain_tumor_dataset/yes/Y36.JPG (deflated 42%)
#   adding: content/archive/brain_tumor_dataset/yes/Y108.jpg (deflated 15%)
#   adding: content/archive/brain_tumor_dataset/yes/Y165.JPG (deflated 39%)
#   adding: content/archive/brain_tumor_dataset/yes/Y85.JPG (deflated 34%)
#   adding: content/archive/brain_tumor_dataset/yes/Y166.JPG (deflated 34%)
#   adding: content/archive/brain_tumor_dataset/yes/Y117.JPG (deflated 32%)
#   adding: content/archive/brain_tumor_dataset/yes/
jpg (deflated 9%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_30 no_0_429.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_no 99_0_248.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_21 no_0_5722.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_no 99_0_2667.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_24 no_0_5063.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_24 no_0_6456.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_45 no_0_9338.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_No20_0_6314.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_36 no_0_8706.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_6 no_0_8319.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_7 no_0_7214.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_No15_0_9746.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_1 no._0_2399.jpg (deflated 6%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_47 no_0_7011.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_50 no_0_9076.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_12 no_0_6168.jpg (deflated 10%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_no 2_0_7788.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_50 no_0_8961.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_40 no_0_6860.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_41 no_0_9608.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/no/aug_N20_0_2260.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/augmented_data/.ipynb_checkpoints/ (stored 0%)
#   adding: content/archive/brain_tumor_dataset/no/ (stored 0%)
#   adding: content/archive/brain_tumor_dataset/no/14 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/41 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/no 100.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/no 4.jpg (stored 0%)
#   adding: content/archive/brain_tumor_dataset/no/no 89.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/no/No21.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/No11.jpg (deflated 10%)
#   adding: content/archive/brain_tumor_dataset/no/no 90.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/no/No16.jpg (deflated 11%)
#   adding: content/archive/brain_tumor_dataset/no/31 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/no 3.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/no 6.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/N17.jpg (deflated 9%)
#   adding: content/archive/brain_tumor_dataset/no/N26.JPG (deflated 38%)
#   adding: content/archive/brain_tumor_dataset/no/N6.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/18 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/8 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/40 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/No17.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/42 no.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/no/36 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/no 91.jpeg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/34 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/no 98.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/no 1.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/no 9.png (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/no/No19.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/no 10.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/20 no.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/no/N3.jpg (stored 0%)
#   adding: content/archive/brain_tumor_dataset/no/No22.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/44no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/no 94.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/19 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/4 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/22 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/32 no.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/no/No20.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/37 no.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/no/No13.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/no 2.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/no/6 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/28 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/45 no.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/no/no 95.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/10 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/no 923.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/9 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/no 5.jpeg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/47 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/N2.JPG (deflated 40%)
#   adding: content/archive/brain_tumor_dataset/no/29 no.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/46 no.jpg (deflated 12%)
#   adding: content/archive/brain_tumor_dataset/no/23 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/24 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/no 96.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/38 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/35 no.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/no/39 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/No14.jpg (deflated 6%)
#   adding: content/archive/brain_tumor_dataset/no/no 99.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/N20.JPG (deflated 39%)
#   adding: content/archive/brain_tumor_dataset/no/N22.JPG (deflated 35%)
#   adding: content/archive/brain_tumor_dataset/no/48 no.jpeg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/No12.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/no/N15.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/N21.jpg (deflated 11%)
#   adding: content/archive/brain_tumor_dataset/no/N1.JPG (deflated 29%)
#   adding: content/archive/brain_tumor_dataset/no/15 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/50 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/2 no.jpeg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/43 no.jpg (deflated 4%)
#   adding: content/archive/brain_tumor_dataset/no/No18.jpg (deflated 0%)
#   adding: content/archive/brain_tumor_dataset/no/no 92.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/3 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/N19.JPG (deflated 27%)
#   adding: content/archive/brain_tumor_dataset/no/No15.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/no 7.jpeg (deflated 10%)
#   adding: content/archive/brain_tumor_dataset/no/25 no.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/13 no.jpg (deflated 5%)
#   adding: content/archive/brain_tumor_dataset/no/N5.jpg (deflated 2%)
#   adding: content/archive/brain_tumor_dataset/no/N11.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/no/1 no.jpeg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/no 8.jpg (deflated 9%)
#   adding: content/archive/brain_tumor_dataset/no/no 97.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/N16.jpg (deflated 10%)
#   adding: content/archive/brain_tumor_dataset/no/26 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/33 no.jpg (deflated 7%)
#   adding: content/archive/brain_tumor_dataset/no/17 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/5 no.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/no/21 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/30 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/11 no.jpg (deflated 8%)
#   adding: content/archive/brain_tumor_dataset/no/27 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/7 no.jpg (deflated 1%)
#   adding: content/archive/brain_tumor_dataset/no/49 no.jpg (deflated 3%)
#   adding: content/archive/brain_tumor_dataset/no/12 no.jpg (deflated 6%)

# %%
# copy it there
# !cp archive.zip /content/drive/MyDrive
